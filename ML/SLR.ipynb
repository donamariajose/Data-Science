# %%
# supervised learning
# simple linear regression algorithm based data model
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# reading data
data=pd.read_csv('C:/Users/donad/OneDrive/Desktop/Internship/1_Machine Learning/4_Supervised_Learning/Regression/Datasets/test.csv')
data
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
# check for null value
data.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
# check for dupplicates
data.duplicated().sum()
# Out:
# 0

# %%
# # check data correlation
data.corr()
# Out:
#           x         y
# x  1.000000  0.994545
# y  0.994545  1.000000

# %%
# splitting to train and test
x=data[['x']]
y=data[['y']]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# model building
slr=LinearRegression()
slr.fit(xtrain,ytrain)
predlr=slr.predict(xtest)
predlr
# Out:
# array([[ 11.69909749],
#        [ 78.47494023],
#        [ 11.69909749],
#        [ 64.31036753],
#        [ 94.66302332],
#        [ 27.88718058],
#        [ 20.80489423],
#        [100.73355448],
#        [ 71.39265388],
#        [ 89.60424736],
#        [ 58.23983637],
#        [ 65.32212272],
#        [ 97.6982889 ],
#        [ 99.72179929],
#        [ 18.78138384],
#        [ 66.33387792],
#        [ 97.6982889 ],
#        [ 31.93420135],
#        [  4.61681114],
#        [ 27.88718058],
#        [ 46.09877406],
#        [ 59.25159157],
#        [  6.64032153],
#        [ 79.48669543],
#        [ 72.40440908],
#        [ 56.21632599],
#        [ 56.21632599],
#        [ 82.52196101],
#        [ 34.96946693],
#        [ 74.42791946],
#        [ 67.34563311],
#        [ 27.88718058],
#        [ 14.73436307],
#        [ 56.21632599],
#        [ 15.74611826],
#        [ 60.26334676],
#        [ 11.69909749],
#        [ 26.87542539],
#        [ 59.25159157],
#        [ 73.41616427],
# ...

# %%
ytest
# Out:
#               y
# 218    9.241139
# 126   74.499360
# 123    7.468502
# 130   67.386547
# 152   97.001484
# 75    31.322749
# 1     23.177279
# 221  103.526616
# 140   70.343297
# 22    89.826344
# 278   53.520423
# 136   68.946998
# 181  101.069788
# 30    97.551553
# 280   21.426378
# 114   67.017160
# 113   97.703422
# 177   36.062930
# 231    5.634031
# 239   28.156685
# 241   52.054907
# 284   60.917927
# 220    9.281700
# 26    78.310565
# 197   69.398585
# 272   56.014481
# 173   54.554470
# 64    85.455042
# 148   34.853482
# 235   72.913885
# 208   68.488207
# 134   29.317700
# 5      9.805235
# 82    49.830518
# 163   21.165239
# 253   60.111350
# 132   12.079916
# 81    23.444792
# 88    56.824570
# 142   75.758418
# 211   41.903689
# 48    38.147539
# 103   75.692986
# 214   23.526472
# 192   80.971443
# 27    19.131510
# 94    60.910543
# 150   59.831397
# 170   79.447695
# 107   98.132580
# 219    7.646530
# 234   66.614996
# 58    70.914643
# 149   -2.819914
# ...

# %%
# printing mean squared error
print(mean_squared_error(predlr,ytest))
# Out:
# 9.330587497927127

# %%
# ploting graph
import matplotlib.pyplot as plt
plt.scatter(x=data['x'],y=data['y'])
plt.title('LinearRegression')
plt.grid()
plt.show()
